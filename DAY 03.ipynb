# %% [markdown]
# # © 2022 by <b> Aspire Academy </b>, All Rights Reserved.

# %% [markdown]
# <center> <h1> DATA VISUALIZATION USING PYPLOT </h1></center>

# %% [markdown]
# ![PART1](assets/PYPLOT.png)

# %% [markdown]
# <center> <h1> "A picture is worth a thousand words." </h1></center>

# %% [markdown]
# ## INTRODUCTION
#
# Visualization is the easiest way to analyze and absorb information because the way human brain processes information, using charts or graphs to visualize large amounts of complex data, is much easier than poring over spreadsheets or reports.
#
# It is the first step towards any kind of data analysis work.
#
# Visuals, better known as **Data Visualization**, help us to easily understand complex problem and see certain patterns.
#
# Visuals also help in identifying patterns, relationships and outliers in data and in understanding business problems better and quickly.
#
# Insights gathered from the visuals help in building strategies for businesses.
#
# Data Visualization basically refers to the graphical or visual representation of information and data using visual elements like charts, graphs, maps, etc.
#
# In Python, we can use two exclusive libraries for visualization, commonly known as **matplotlib** and **seaborn**.

# %% [markdown]
# ## MATPLOTLIB
#     -- Data is only as good as it is presented
#
# + It is a 2D plotting library that helps in visualizing figure.
# + Matplotlib is usned in Python as it is a robust, free and easy library for data visualization.
# + It is easy to learn and understand
# + It was originally written by **J.D. Hunter** and is actively being developed by a full-fledged community.
# + **Pyplot** is a module of matplotlib library (of Python) containing of methods which allows a user to create 2D plots and graphs easily and interactively

# %% [markdown]
# ## Pyplot
#
# + It is the state-machine interface to the plotting library in matplotlib.
# + In this figure and axes are implicitly and automatically created to achieve the desired plot.
# + For Example, calling **plot()** function from pyplot module will automatically create the necessary figure and axes ro achieve the desired plot.
# + Setting a title will then automatically set that title to the current object axes.
# + The pyplot interface is generally preferred for non-interactive plottinh (i.e, scripting)
# + Each pyplot function makes some changes to a figure, like creating a figure, creating a plotting area in a figure, plotting some lines in a plotting some lines in a plotting area, decorating the plot with labels etc.,

# %% [markdown]
# ## INSTALLING MATPLOTLIB

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## TYPES OF VISUALIZATION

# %%
line plot, scatter plot, histogram, box plot, bar chart, pie chart
# Out:
#   File "/tmp/ipykernel_2566/1587652182.py", line 1
#     line plot, scatter plot, histogram, box plot, bar chart, pie chart
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## BASIC VISUALIZATION RULES
#
# 1. Before you plot/create any chart or graph type, make sure to import the matplotlib.pyplot library by giving the command:
#
# ```python
# import matplotlib.pyplot
#
#          OR
#
# import matplotlib.pyplot as plt
# ```
# 2. Along with pyplot, if your are using NumPy functionality, make sure to import it also using the command:
#
# ```python
# import numpy as np
# ```
#
# 3. The next step is to choose an **appropriate** plot type. If there are various options, we should compare them and choose the one that fits our model the best.
#
# 4. lable the axis
#
# 5. add a title to make our plot more informative
#
# 6. add labels for different categories when needed
#
# 7. optionally we can add a text or an arrow at relevant data points
#
# 8. In some cases, we can use some sizes and colours of the data to make the plot more informative

# %% [markdown]
# ## BASIC NOMENCLATURE OF A PLOT

# %% [markdown]
# ![PLOT](assets/bar-graph.png)

# %% [markdown]
# + **Figure**: It is the outermost figure which may contain one or more than one axes(plots)
# + **Axes**: It is what we generally think of as a plot. A Figure can contain many Axes. It contains two or three (in the case of 3D) Axis object. Each Axis has a **title**, an **x-label** and a **y-label**
# + **Axis**:

# %% [markdown]
# ## LINE PLOT/CHART

# %%
#simple line chart using two lists
# %matplotlib inline

import matplotlib.pyplot as plt
plt.plot([1,2,3], [5,7,4])  # plotting two lists
plt.show() # display the chart

# %%
# program to draw two lines along with proper titles and legends
import matplotlib.pyplot as plt

x = [1,2,3]
y = [5,7,4]

plt.plot(x,y,label = "First Line") #plotting two lists with appropriate label

x2 = [1,2,3]
y2 = [10,11,14]
plt.plot(x2,y2, label = 'Second Line')

plt.xlabel("Plot number")
plt.ylabel("Important Variables")

plt.title("New Graph")
plt.legend()  #involves a legend

plt.show()  #displaying the chart

# %% [markdown]
# ## Multiple Views

# %%
# plotting line chart in different views
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 20.0, 1)
s = list(range(1,21))
s2 = list(range(4,24))

plt.subplot(2,1,1) # the figure has 2 row, 1 columns, and this plot is the first plot. 
plt.plot(t,s)
plt.ylabel("Values")
plt.title("First Chart")
plt.grid(True)

plt.subplot(2,1,2) # the figure has 2 row, 1 columns, and this plot is the second plot.
plt.plot(t,s2)
plt.xlabel("Item (s)")
plt.ylabel('Value')
plt.title("\n\n Second Chart")
plt.grid(True)

plt.show()

# %%
# plotting line chart in different views
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 20.0, 1)
s = list(range(1,21))
s2 = list(range(4,24))

plt.subplot(1,2,1) #the figure has 1 row, 2 columns, and this plot is the first plot. 
plt.plot(t,s)
plt.ylabel("Values")
plt.title("First Chart")
plt.grid(True)

plt.subplot(1,2,2) #the figure has 1 row, 2 columns, and this plot is the second plot. 
plt.plot(t,s2)
plt.xlabel("Item (s)")
plt.ylabel('Value')
plt.title("\n\n Second Chart")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Adjusting the space between the subplots

# %%
# plotting line chart in different views
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 20.0, 1)
s = list(range(1,21))
s2 = list(range(4,24))

plt.subplot(2,1,1) # the figure has 2 row, 1 columns, and this plot is the first plot. 
plt.plot(t,s)
plt.ylabel("Values")
plt.title("First Chart")
plt.grid(True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.5)  # ADJUST the Spacing between

plt.subplot(2,1,2) # the figure has 2 row, 1 columns, and this plot is the second plot.
plt.plot(t,s2)
plt.xlabel("Item (s)")
plt.ylabel('Value')
plt.title("\n\n Second Chart")
plt.grid(True)

plt.show()

# %%
#Program to plot frequency of marks using line chart

import matplotlib.pyplot as plt

def fnplot(list):
    plt.plot(list1)
    plt.title("Marks Line Chart")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.show()
    
list1 = [50,50,50,65,65,75,75,80,80,90,90,90]
fnplot(list1)

# %%
#program for plotting sine wave using line chart
import matplotlib.pyplot as plt
import numpy as np

xvals = np.arange(-10,10,0.01)
yvals = np.sin(xvals)
plt.plot(xvals, yvals)
plt.show()

# %%
#program to evaluate an algebraic expression 10x+14 using line chart

import numpy as np
from matplotlib import pyplot as plt

x = np.arange(12,20)
y = 10*x + 14

plt.title("Graph for an Algebraic Expression")
plt.xlabel("x axis")
plt.ylabel("y label")

plt.plot(x,y)
plt.show()

# %%
# Program to plot a quadratic equation using dashed line chart
# 1 - 0.5*x**2

import numpy as np
from matplotlib import pyplot as plt

xvals = np.arange(-2, 1, 0.01)
newyvals = 1 - 0.5* xvals **2

plt.plot(xvals, newyvals, 'b--')
plt.title("Example plots")
plt.xlabel("Input")
plt.ylabel("Function Values")
plt.show()

# %% [markdown]
# ## CHANGING LINE COLOURS AND STYLES

# %%
#Multiple lines with multiple colors given explicitly

import matplotlib.pyplot as plt
import numpy as np

y = np.arange(1,3)
plt.plot(y, 'y')
plt.plot(y+1, 'm')
plt.plot(y+2, 'c')
plt.show()

# %% [markdown]
# ## COLOUR ABBREVIATION
#
# | COLOUR ABBREVIATION        |  Colour Name                                     |
# | ---------------------------| -----------------------------------------------  |
# | b                          | blue                                             |
# | c                          | cyan                                             |
# | g                          | green                                            |
# | k                          | black                                            |
# | m                          | magenta                                          |
# | r                          | red                                              |
# | w                          | white                                            |
# | y                          | yello                                            |
#
#
# ## STYLE ABBREVIATION
#
# | STYLE ABBREVIATION         |  Style                                           |
# | ---------------------------| -----------------------------------------------  |
# | -                          | solid line                                       |
# | --                         | dashed line                                      |
# | -.                         | dash-dot line                                    |
# | :                          | dotted line                                      |

# %%
# program to exhibit different line styles

import matplotlib.pyplot as plt
import numpy as np

y = np.arange(1,3)
plt.plot(y, '--', y+1, '-.', y+2, ':')
plt.show()

# %% [markdown]
# # PIE PLOT/CHART

# %%
import matplotlib.pyplot as plt

#Data to plot
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)

plt.pie(sizes, explode = explode, labels = labels, colors = colors, shadow = True, startangle = 140)

plt.axis('equal')
plt.show()

# %% [markdown]
# # SCATTER CHART

# %%
import matplotlib.pyplot as plt

weight = [83.3, 74, 64.5, 79, 90, 84.8, 84, 88,66,77, 79, 90.5, 74.3, 90, 73]
height = [167, 113.7, 124.8, 165.5, 145.4, 155, 149, 180, 169.5, 156, 167.3, 145, 185, 181, 168.3]

plt.scatter(weight, height)

plt.xlabel('weight')
plt.ylabel('height')

plt.title('Scatter plot-height vs weight', fontsize = 20)
plt.show()

# %%
import matplotlib.pyplot as plt

weight = [83.3, 74, 64.5, 79, 90, 84.8, 84, 88,66,77, 79, 90.5, 74.3, 90, 73]
height = [167, 113.7, 124.8, 165.5, 145.4, 155, 149, 180, 169.5, 156, 167.3, 145, 185, 181, 168.3]

plt.scatter(weight, height, c = 'r', marker = '*')

plt.xlabel('weight', fontsize = 16)
plt.ylabel('height', fontsize = 16)

plt.title('Scatter plot-height vs weight', fontsize = 20)
plt.show()

# %%
#to plot a scatter chart using randomly generated datasets.

import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000)
y = np.random.randn(1000)

plt.scatter(x,y)
plt.show()

# %%
# to plot a scatter chart using randomly generated data sets with different color and sizes for each point

import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000)
y = np.random.randn(1000)

size = 50*np.random.randn(1000)
colors = np.random.rand(1000)

plt.scatter(x,y, s = size, c = colors)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# # BAR PLOT/CHART

# %%
#To plot a simple bar chart

import matplotlib.pyplot as plt

y_axis = [20,50,30]
x_axis = range(len(y_axis))

plt.bar(x_axis, y_axis, width = 0.5, color = 'orange')
plt.show()

# %%
#to plot two list elements using bar chart

import matplotlib.pyplot as plt

x = [2,4,6,8,10]
y = [6,7,8,2,4]

x2 = [1,3,5,7,9]
y2 = [7,8,2,4,2]

plt.bar(x,y, label = "Bars1")
plt.bar(x2, y2, label = "bars2")

plt.xlabel('x')
plt.ylabel('y')

plt.title("Bar Graph \n With multiline title")
plt.legend()
plt.show()

# %%
#program to plot a bar chart showing the choice of favourite movie among the people

import numpy as np
import matplotlib.pyplot as plt

objects = {'Comedy', 'Action', 'Romance', 'Drama', 'SciFi'}
y_pos = np.arange(len(objects))

types = (4,5,6,1,4)
plt.bar(y_pos, types, align = 'center', color = 'blue')

plt.xticks(y_pos, objects)

plt.ylabel("People")
plt.title("Favourite Type of Movie")
plt.show()

# %% [markdown]
# # HISTOGRAMS

# %%
#to plot a simple histogram of random values

import matplotlib.pyplot as plt
import numpy as np

y = np.random.randn(1000)
plt.hist(y)
plt.show()

# %%
#to plot a simple histogram of random values with bins as 25

import matplotlib.pyplot as plt
import numpy as np

y = np.random.randn(1000)
plt.hist(y, 25) #bins = 25
plt.show()

# %%
#to plot a simple histogram of random values with bins as 25

import matplotlib.pyplot as plt
import numpy as np

y = np.random.randn(1000)
plt.hist(y, 25, edgecolor = 'red')
plt.show()

# %%
#to plot a histogram for number of students with their respective weights

import matplotlib.pyplot as plt

data_students = [5,15,25,35,45,55]
plt.hist(data_students, bins = [0,10,20,30,40,50,60], weights = [20,10,45,33,6,8], edgecolor = "red")
plt.show()

# %%
#to plot a histogram with different formatting and suitable title and labels

import numpy as np
import matplotlib.pyplot as plt

data_students = [1,11,21,31,41,51]

plt.hist(data_students, 
         bins = [0,10,20,30,40,50,60], 
         weights = [10, 1, 0, 33, 6,8], 
         facecolor = 'y', 
         edgecolor = 'red'
        )

plt.title("Histogram for students data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.savefig("student.png")
plt.show()

# %% [markdown]
# ## FREQUENCY PLOYGONS

# %%
#to construct a frequency polygon on the basis of student_data v/s weight histogram

import numpy as np
import matplotlib.pyplot as plt

data = [5,15,25,35,15,55]
plt.hist(data, bins = [0,10,20,30,40,50,60], weights = [20,10,45,33,6,6],
        edgecolor = 'red', histtype = 'step')


plt.xlabel("Value")
plt.ylabel("Probability")
plt.title("Histogram")
plt.show()

# %% [markdown]
# ## BOX PLOT

# %%
#to plot a simple boxplot

import matplotlib.pyplot as plt

list1 = [43,76,34,63,56,82,87,55,64,87,95,23,14,65,67,25,23,85]
list2 = [34,45,34,23,43,76,26,18,24,74,23,56,23,23,34,56,32,23]

data = [list1, list2]

plt.boxplot(data)
plt.show()

# %% [markdown]
# # © 2022 by <b> Aspire Academy </b>, All Rights Reserved.
